# %% [markdown]
# # Welcome To Vocos Vocoder Trainer

# %%
# %cd /content/drive/MyDrive/aiflow

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Download The Dataset

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/archive-en.zip', 'r') as zip_ref: zip_ref.extractall('/content/Yuna')

# %% [markdown]
# ## Training

# %%
# !python -m aiflow.models.yuna_speech.vocos.train -c config.json
