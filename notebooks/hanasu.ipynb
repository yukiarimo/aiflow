# %% [markdown]
# # Welcome to Hanasu TTS Trainer

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/aiflow
# !pip install -e .
# !apt-get update && apt-get install -y espeak-ng
# !pip install phonemizer
# !pip install unidic-lite
# !pip install librosa==0.9.1
# !pip install tensorboard==2.12.0 tensorflow==2.12.0
# !pip install matplotlib==3.7.0 # This fixes: 'FigureCanvasAgg' object has no attribute 'tostring_rgb'
# !pip install numpy==1.26.4
# %cd aiflow/models/hanasu/monotonic_align
# !python setup.py build_ext --inplace
# %cd ../../../

# %% [markdown]
# ## Download the dataset

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Archive.zip', 'r') as zip_ref: zip_ref.extractall('/content/Yuna')

# %% [markdown]
# ## Bug Fixes

# %%
import os
directory = '/content/Yuna/'
for root, dirs, files in os.walk(directory):
	for filename in files:
		if filename.endswith(".mel.pt"):
			os.remove(os.path.join(root, filename))
for root, dirs, files in os.walk(directory):
	for filename in files:
		if filename.endswith(".spec.pt"):
			os.remove(os.path.join(root, filename))

# %% [markdown]
# # Training

# %%
# %cd /content/drive/MyDrive/aiflow
# Note: logs folder is created where you are

# %%
# !python -m aiflow.models.hanasu.train -c aiflow/models/hanasu/config.json -m Yuna

# %%
import os
os.runtime.unassigned_runtime_shutdown()

# %% [markdown]
# # Inference

# %%
from aiflow.models.hanasu.models import inference, load_model
model = load_model("./configs/config.json", "/Users/yuki/Downloads/G_10000.pth", device="mps")

# %%
text ="Text for generation."
# Or you can read from a file:
# with open("../output.txt", 'r', encoding='utf-8') as f: text = f.read()

# %%
# No streaming inference
result = inference(model=model, text=text, sid=0, noise_scale=0.0, noise_scale_w=0.0, length_scale=1, device="mps", stream=False, output_file="test.wav", language="en-us", duration_blur_sigma=0.1, temperature=1)

# %%
# Voice Conversion Inference
from aiflow.models.hanasu.models import voice_conversion_inference

# Perform voice conversion
converted_audio = voice_conversion_inference(
	model=model,
	source_wav_path="input.wav",
	source_speaker_id=1,
	target_speaker_id=0,
	device="mps"
)

write(data=converted_audio, rate=48000, filename="voice_converted_audio.wav")

# %% [markdown]
# # Export

# %%
from aiflow.models.hanasu.models import export_onnx, synthesize

export_onnx("/Users/yuki/Downloads/G_15000.pth", "/Users/yuki/Documents/Github/hanasu/hanasu/configs/config.json", "output.onnx")

# %%
synthesize("/Users/yuki/Documents/Github/hanasu/hanasu/output.onnx", "/Users/yuki/Documents/Github/hanasu/hanasu/configs/config.json", "output.wav", "Hello, world!", sid=0, scales=[0.2, 1.0, 1.0])
