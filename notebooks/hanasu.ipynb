# %% [markdown]
# # Welcome To Hanasu TTS Trainer

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/aiflow

# %%
# !apt-get update && apt-get install -y espeak-ng
# !pip install -r requirements.txt
# !pip install librosa==0.9.1
# !pip install tensorboard==2.12.0 tensorflow==2.12.0
# !pip install matplotlib==3.7.0 # This fixes: 'FigureCanvasAgg' object has no attribute 'tostring_rgb'
# !pip install numpy==1.26.4

# %% [markdown]
# ## Download The Dataset

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/archive-en.zip', 'r') as zip_ref: zip_ref.extractall('/content/Yuna')

# %% [markdown]
# ## Training

# %%
# !python -m aiflow.models.yuna_speech.hanasu.preprocess --filelist filelist.txt --force --cache-dir "/content/Yuna/data"

# %%
# !python -m aiflow.models.yuna_speech.hanasu.train --filelist filelist.txt --cache-dir "/content/Yuna/data"

# %% [markdown]
# ## Inference

# %%
# !python -m aiflow.models.yuna_speech.hanasu.infer \
--checkpoint checkpoints/latest.pt \
--text "Honor the vessel" \
--speaker Yuna \
--language en-us \
--vocos-dir vocos \
--out samples/test.wav \
--normalize-wav \
--no-postnet \
